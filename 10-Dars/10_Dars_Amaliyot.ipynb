# %% [markdown]
# # Data Collection

# %% [markdown]
# # Data Setni CSV fayldan ochish

# %%
import pandas as pd
df = pd.read_csv('AirQuality.csv')

# %% [markdown]
# # Data Setni URL bo`yicha ochish

# %%
url = "https://github.com/Afkerian/Beijing-Multi-Site-Air-Quality-Data-Data-Set/blob/main/data/beijing%2Bmulti%2Bsite%2Bair%2Bquality%2Bdata/data.csv"
df = pd.read_csv(url)

# %% [markdown]
# # Data Setni EXCEL fayldan ochish

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
df = pd.read_excel('Iris_dataset.xlsx', sheet_name='Sheet1')
print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Data Setni SQL DATABASE orqali ochish

# %%
import sqlite3
import pandas as pd


conn = sqlite3.connect('soccer_database.db')


df = pd.read_sql_query("SELECT * FROM players", conn)
conn.close()

print(df.head())
# Out:
#    id               name  age  team_id    position
# 0   1       Lionel Messi   36        1     Forward
# 1   2  Cristiano Ronaldo   39        3     Forward
# 2   3    Marcus Rashford   26        2     Forward
# 3   4              Pedri   21        1  Midfielder

# %% [markdown]
# # Data Setni NO SQL DATABASE orqali ochish

# %%
pip install pymongo
# Out:
# ...
#    ---------------------------------------- 0.0/955.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/955.1 kB ? eta -:--:--
#    --------------------- ------------------ 524.3/955.1 kB 2.8 MB/s eta 0:00:01
#    ---------------------------------------- 955.1/955.1 kB 4.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient("mongodb://localhost:27017/")  
db = client["soccer_database"]
collection = db["players"]
cursor = collection.find()  
df = pd.DataFrame(list(cursor))
df.drop(columns=['_id'], inplace=True, errors='ignore')
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[9], line 8
#       6 collection = db["players"]
#       7 cursor = collection.find()
# ----> 8 df = pd.DataFrame(list(cursor))
#       9 df.drop(columns=['_id'], inplace=True, errors='ignore')
#      10 print(df.head())
#
# File c:\Users\Rasulbek_Ruzmetov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1284, in Cursor.__next__(self)
#    1283 def __next__(self) -> _DocumentType:
# -> 1284     return self.next()
#
# File c:\Users\Rasulbek_Ruzmetov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pymongo\synchronous\cursor.py:1260, in Cursor.next(self)
#    1258 if self._empty:
#    1259     raise StopIteration
# -> 1260 if len(self._data) or self._refresh():
#    1261     return self._data.popleft()
#    1262 else:
#
# ...

# %% [markdown]
# # Data Setni API KEY  orqali ochish

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd

url = "https://api.football-data.org/v2/players"
headers = {"X-Auth-Token": "YOUR_API_KEY"}

response = requests.get(url, headers=headers)
data = response.json()

df = pd.json_normalize(data['players'])
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 10
#       7 response = requests.get(url, headers=headers)
#       8 data = response.json()
# ---> 10 df = pd.json_normalize(data['players'])
#      11 print(df.head())
#
# KeyError: 'players'

# %% [markdown]
# # Data Setni Web Scrapping orqali ochish

# %%
pip install beautifulsoup4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup

url = 'https://example.com/players'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')


rows = soup.find_all('tr')
data = []

for row in rows:
    cols = row.find_all('td')
    data.append([col.text.strip() for col in cols])

import pandas as pd
df = pd.DataFrame(data)
print(df.head())
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Data Setni Google Sheet Orqali yuklash

# %%
sheet_url = "https://docs.google.com/spreadsheets/d/FILE_ID/export?format=csv"
df = pd.read_csv(sheet_url)
print(df.head())

# %% [markdown]
# # Data Setni qo`lda yaratish

# %%
data = {
    'player': ['Messi', 'Ronaldo', 'Mbappe'],
    'goals': [30, 25, 28],
    'xG': [26.5, 23.8, 29.1]
}
df = pd.DataFrame(data)
print(df)
# Out:
#     player  goals    xG
# 0    Messi     30  26.5
# 1  Ronaldo     25  23.8
# 2   Mbappe     28  29.1

# %% [markdown]
# # Data Set ustida amallar bajaramiz

# %%
import pandas as pd

df = pd.read_csv('AmesHousing.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order            2930 non-null   int64
#  1   PID              2930 non-null   int64
#  2   MS SubClass      2930 non-null   int64
#  3   MS Zoning        2930 non-null   object
#  4   Lot Frontage     2440 non-null   float64
#  5   Lot Area         2930 non-null   int64
#  6   Street           2930 non-null   object
#  7   Alley            198 non-null    object
#  8   Lot Shape        2930 non-null   object
#  9   Land Contour     2930 non-null   object
#  10  Utilities        2930 non-null   object
#  11  Lot Config       2930 non-null   object
#  12  Land Slope       2930 non-null   object
#  13  Neighborhood     2930 non-null   object
#  14  Condition 1      2930 non-null   object
#  15  Condition 2      2930 non-null   object
# ...

# %%
df.head()
# Out:
#    Order        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      1  526301100           20        RL         141.0     31770   Pave
# 1      2  526350040           20        RH          80.0     11622   Pave
# 2      3  526351010           20        RL          81.0     14267   Pave
# 3      4  526353030           20        RL          93.0     11160   Pave
# 4      5  527105010           60        RL          74.0     13830   Pave
#
#   Alley Lot Shape Land Contour  ... Pool Area Pool QC  Fence Misc Feature  \
# 0   NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1   NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2   NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4   NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
#
#   Misc Val Mo Sold Yr Sold Sale Type  Sale Condition  SalePrice
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df.fillna(df.median(numeric_only=True), inplace=True)


df.drop(columns=['Order', "Alley"], inplace=True, errors='ignore')

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

class DataPreprocessing:
    def __init__(self, df):
        self.df = df.copy() 
        self.encoder = LabelEncoder()
        self.scaler = StandardScaler()

    def tozala(self):
        for col in self.df.columns:
            if self.df[col].isnull().any():
                if self.df[col].dtype == 'object':
                    self.df[col] = self.df[col].fillna(self.df[col].mode()[0])
                else:
                    self.df[col] = self.df[col].fillna(self.df[col].mean())
        return self

    def encodla(self):
        for col in self.df.columns:
            if self.df[col].dtype == 'object':
                if self.df[col].nunique() <= 6:
                    dummies = pd.get_dummies(self.df[col], prefix=col, dtype=int)
                    self.df = pd.concat([self.df.drop(columns=[col]), dummies], axis=1)
                else:
                    self.df[col] = self.encoder.fit_transform(self.df[col])
        return self

    def scaling_qil(self):
        numeric_cols = self.df.select_dtypes(include=['int64', 'float64']).columns.drop('Survived')
        self.df[numeric_cols] = self.scaler.fit_transform(self.df[numeric_cols])
        return self
     
   

    def get_df(self):
        return self.df

# %%
df.head()
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0  526301100           20        RL         141.0     31770   Pave       IR1
# 1  526350040           20        RH          80.0     11622   Pave       Reg
# 2  526351010           20        RL          81.0     14267   Pave       IR1
# 3  526353030           20        RL          93.0     11160   Pave       Reg
# 4  527105010           60        RL          74.0     13830   Pave       IR1
#
#   Land Contour Utilities Lot Config  ... Pool Area Pool QC  Fence  \
# 0          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 1          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
# 2          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 3          Lvl    AllPub     Corner  ...         0     NaN    NaN
# 4          Lvl    AllPub     Inside  ...         0     NaN  MnPrv
#
#   Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type  Sale Condition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2930 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   object
#  6   Lot Shape        2930 non-null   object
#  7   Land Contour     2930 non-null   object
#  8   Utilities        2930 non-null   object
#  9   Lot Config       2930 non-null   object
#  10  Land Slope       2930 non-null   object
#  11  Neighborhood     2930 non-null   object
#  12  Condition 1      2930 non-null   object
#  13  Condition 2      2930 non-null   object
#  14  Bldg Type        2930 non-null   object
#  15  House Style      2930 non-null   object
# ...

# %%
df["Bldg Type"].unique()
# Out:
# array(['1Fam', 'TwnhsE', 'Twnhs', 'Duplex', '2fmCon'], dtype=object)

# %%
df["Lot Shape"].unique()
# Out:
# array(['IR1', 'Reg', 'IR2', 'IR3'], dtype=object)

# %%
df["House Style"].unique()
# Out:
# array(['1Story', '2Story', '1.5Fin', 'SFoyer', 'SLvl', '2.5Unf', '1.5Unf',
#        '2.5Fin'], dtype=object)

# %% [markdown]
# # Feature Enginering

# %%
df['Lot Shape'] = df['IR1'] - df['Reg'] - df["IR2"] - df["IR3"]
df['Bldg Type'] = df['1Fam'] - df['TwnhsE'] - df["Twnhs"]  - df["Duplex"] - df["2fmCon"]
 

df['House Style'] = {
    '1Story':10,
    '2Story':8,
    '1.5Fin':6,
    'SFoyer':4,
    'SLvl':2,
    '2.5Unf':3,
    '1.5Unf':1,
    '2.5Fin':5

}

df.replace([float('inf'), -float('inf')], 0, inplace=True)
df.fillna(0, inplace=True)

# %%
df['Street'] = df['Year Built'] + df['Year Remod/Add'] + 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2930 entries, 0 to 2929
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2930 non-null   int64
#  1   MS SubClass      2930 non-null   int64
#  2   MS Zoning        2930 non-null   object
#  3   Lot Frontage     2930 non-null   float64
#  4   Lot Area         2930 non-null   int64
#  5   Street           2930 non-null   int64
#  6   Lot Shape        2930 non-null   object
#  7   Land Contour     2930 non-null   object
#  8   Utilities        2930 non-null   object
#  9   Lot Config       2930 non-null   object
#  10  Land Slope       2930 non-null   object
#  11  Neighborhood     2930 non-null   object
#  12  Condition 1      2930 non-null   object
#  13  Condition 2      2930 non-null   object
#  14  Bldg Type        2930 non-null   object
#  15  House Style      2930 non-null   object
#  16  Overall Qual     2930 non-null   int64
# ...

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

x = df.drop(columns=['SalePrice'])
y = df['SalePrice'].astype(int)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
import pandas as pd

x_train = pd.DataFrame({
    'Zone': ['RL', 'RM', 'RH'],
    'Area': [8450, 9600, 11250]
})
y_train = [208500, 181500, 223500]

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
x_train['Zone'] = le.fit_transform(x_train['Zone'])

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor()
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor()
model.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor()

# %%
print(x_train.select_dtypes(include='object').columns)
# Out:
# Index(['MS Zoning', 'Lot Shape', 'Land Contour', 'Utilities', 'Lot Config',
#        'Land Slope', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type',
#        'House Style', 'Roof Style', 'Roof Matl', 'Exterior 1st',
#        'Exterior 2nd', 'Mas Vnr Type', 'Exter Qual', 'Exter Cond',
#        'Foundation', 'Bsmt Qual', 'Bsmt Cond', 'Bsmt Exposure',
#        'BsmtFin Type 1', 'BsmtFin Type 2', 'Heating', 'Heating QC',
#        'Central Air', 'Electrical', 'Kitchen Qual', 'Functional',
#        'Fireplace Qu', 'Garage Type', 'Garage Finish', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Pool QC', 'Fence', 'Misc Feature',
#        'Sale Type', 'Sale Condition'],
#       dtype='object')

# %%
df_all = pd.concat([x_train, x_test], axis=0)


df_all_encoded = pd.get_dummies(df_all)


x_train_encoded = df_all_encoded.iloc[:len(x_train), :]
x_test_encoded = df_all_encoded.iloc[len(x_train):, :]

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='mean')


x_train_clean = imputer.fit_transform(x_train_encoded)
x_test_clean = imputer.transform(x_test_encoded)
# Out:
# c:\Users\Rasulbek_Ruzmetov\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\impute\_base.py:635: UserWarning: Skipping features without any observed values: ['PID' 'MS SubClass' 'Lot Frontage' 'Lot Area' 'Street' 'Overall Qual'
#  'Overall Cond' 'Year Built' 'Year Remod/Add' 'Mas Vnr Area'
#  'BsmtFin SF 1' 'BsmtFin SF 2' 'Bsmt Unf SF' 'Total Bsmt SF' '1st Flr SF'
#  '2nd Flr SF' 'Low Qual Fin SF' 'Gr Liv Area' 'Bsmt Full Bath'
#  'Bsmt Half Bath' 'Full Bath' 'Half Bath' 'Bedroom AbvGr' 'Kitchen AbvGr'
#  'TotRms AbvGrd' 'Fireplaces' 'Garage Yr Blt' 'Garage Cars' 'Garage Area'
#  'Wood Deck SF' 'Open Porch SF' 'Enclosed Porch' '3Ssn Porch'
#  'Screen Porch' 'Pool Area' 'Misc Val' 'Mo Sold' 'Yr Sold']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# ...

# %%
model.fit(x_train_clean, y_train)
y_pred = model.predict(x_test_clean)
print("r2:", r2_score(y_test, y_pred))
# Out:
# r2: -0.04431069300805435

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.impute import SimpleImputer
import shap

imputer = SimpleImputer(strategy='mean')
X_test_clean = imputer.fit_transform(x_test_encoded)


explainer = shap.Explainer(model)
shap_values = explainer(X_test_clean)


shap.summary_plot(shap_values, X_test_clean, feature_names=x_test_encoded.columns)
# Out:
# c:\Users\Rasulbek_Ruzmetov\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\impute\_base.py:635: UserWarning: Skipping features without any observed values: ['Zone' 'Area']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(

# %%
import joblib

joblib.dump(model, "AmesHousing.pkl")
# Out:
# ['AmesHousing.pkl']
