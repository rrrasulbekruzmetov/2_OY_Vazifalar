# %% [markdown]
# # Logistic regresion bo`yicha modelni train test qilib accuracy score gacha chiqaramiz

# %%
import pandas as pd 
from sklearn.preprocessing import  LabelEncoder
encoder = LabelEncoder()
from sklearn.linear_model  import  LogisticRegression
model= LogisticRegression()

from sklearn.preprocessing import StandardScaler
standart_scaler  = StandardScaler()

from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("loan_approval_dataset.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   object
#  3    self_employed             4269 non-null   object
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   object
# dtypes: int64(10), object(3)
# ...

# %%
df.head()
# Out:
#    loan_id   no_of_dependents      education  self_employed   income_annum  \
# 0        1                  2       Graduate             No        9600000
# 1        2                  0   Not Graduate            Yes        4100000
# 2        3                  3       Graduate             No        9100000
# 3        4                  3       Graduate             No        8200000
# 4        5                  5   Not Graduate            Yes        9800000
#
#     loan_amount   loan_term   cibil_score   residential_assets_value  \
# 0      29900000          12           778                    2400000
# 1      12200000           8           417                    2700000
# 2      29700000          20           506                    7100000
# 3      30700000           8           467                   18200000
# 4      24200000          20           382                   12400000
#
#     commercial_assets_value   luxury_assets_value   bank_asset_value  \
# ...

# %%
df[' loan_status'].nunique()
# Out:
# 2

# %% [markdown]
# # Data preprocessing bosqichi

# %%
for  col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype == "object":
            df[col].fillna(df[col].mode()[0], inplace=True)
        else:
            df[col].fillna(df[col].mean(), inplace=True)

# %% [markdown]
# # Huddishu kodni FUNKSIYALI holati

# %%
def cleaner(df):
    for  col in df.columns:
        if df[col].isnull().any():
            if df[col].dtype == "object":
                df[col].fillna(df[col].mode()[0], inplace=True)
            else:
                df[col].fillna(df[col].mean(), inplace=True)
    return df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    income_annum              4269 non-null   int64
#  3    loan_amount               4269 non-null   int64
#  4    loan_term                 4269 non-null   int64
#  5    cibil_score               4269 non-null   int64
#  6    residential_assets_value  4269 non-null   int64
#  7    commercial_assets_value   4269 non-null   int64
#  8    luxury_assets_value       4269 non-null   int64
#  9    bank_asset_value          4269 non-null   int64
#  10  col_ Graduate              4269 non-null   int64
#  11  col_ Not Graduate          4269 non-null   int64
#  12  col_ No                    4269 non-null   int64
# ...

# %% [markdown]
# # Datani Encoding qilish bosqichi

# %%
for col in df.columns:
    if df[col].dtype == "object":
        if df[col].nunique() <=5:
            dummies = pd.get_dummies(df[col], prefix="col", dtype=int)
            df = pd.concat([df.drop(columns=[col]), dummies], axis=1)

else:
    df[col] = encoder.fit_transform(df[col])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Rasulbek_Ruzmetov\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ' loan_status'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    income_annum              4269 non-null   int64
#  3    loan_amount               4269 non-null   int64
#  4    loan_term                 4269 non-null   int64
#  5    cibil_score               4269 non-null   int64
#  6    residential_assets_value  4269 non-null   int64
#  7    commercial_assets_value   4269 non-null   int64
#  8    luxury_assets_value       4269 non-null   int64
#  9    bank_asset_value          4269 non-null   int64
#  10  col_ Graduate              4269 non-null   int64
#  11  col_ Not Graduate          4269 non-null   int64
#  12  col_ No                    4269 non-null   int64
# ...

# %% [markdown]
# # Data Setni Encoding scaling qilish jarayoni

# %%
numeric_columns = df.select_dtypes(include=["int64"]).columns.drop("col_ Approved")

# %% [markdown]
# # Raqamli ustunlarni aniqlab olamiz / /target ustunini tashlab yuboramiz

# %%
numeric_columns
# Out:
# Index(['loan_id', ' no_of_dependents', ' income_annum', ' loan_amount',
#        ' loan_term', ' cibil_score', ' residential_assets_value',
#        ' commercial_assets_value', ' luxury_assets_value', ' bank_asset_value',
#        'col_ Graduate', 'col_ Not Graduate', 'col_ No', 'col_ Yes',
#        'col_ Rejected'],
#       dtype='object')

# %%
df[numeric_columns] = standart_scaler.fit_transform(df[numeric_columns])

# %%
df.head()
# Out:
#     loan_id   no_of_dependents   income_annum   loan_amount   loan_term  \
# 0 -1.731645          -0.294102       1.617979      1.633052    0.192617
# 1 -1.730834          -1.473548      -0.341750     -0.324414   -0.508091
# 2 -1.730022           0.295621       1.439822      1.610933    1.594031
# 3 -1.729211           0.295621       1.119139      1.721525   -0.508091
# 4 -1.728399           1.475067       1.689242      1.002681    1.594031
#
#     cibil_score   residential_assets_value   commercial_assets_value  \
# 0      1.032792                  -0.780058                  2.877289
# 1     -1.061051                  -0.733924                 -0.631921
# 2     -0.544840                  -0.057300                 -0.107818
# 3     -0.771045                   1.649637                 -0.381263
# 4     -1.264055                   0.757724                  0.735304
#
#     luxury_assets_value   bank_asset_value  col_ Graduate  col_ Not Graduate  \
# ...

# %% [markdown]
# # Data Set ni train va test qismlarga bo`lib olamiz

# %%
x = df.drop("col_ Approved", axis=1)
y=df['col_ Approved']

# %% [markdown]
# # Data Setni train / test / validation / temporary duruhlariga ajratib olamiz

# %%
x_train, x_temp, y_train, y_temp = train_test_split(x, y, test_size=0.2, random_state=42)
x_val, x_test, y_val, y_test = train_test_split(x_temp, y_temp, test_size=0.5, random_state=42)

# %%
model
# Out:
# LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model_pred = model.predict(x_test)

# %%
model_score = accuracy_score(y_test, model_pred)
model_score
# Out:
# 1.0
